# %% [markdown]
# #Death rates for suicide, by sex, race, Hispanic origin, and age: United States

# %%
import pandas as pd
deathrates = pd.read_csv("../data/raw/deathrates.csv")
max_death_row = deathrates.loc[deathrates['ESTIMATE'].idxmax()]
max_death_row
# Out:
# INDICATOR                               Death rates for suicide
# UNIT              Deaths per 100,000 resident population, crude
# UNIT_NUM                                                      2
# STUB_NAME                                     Sex, age and race
# STUB_NAME_NUM                                                 5
# STUB_LABEL                       Male: White: 85 years and over
# STUB_LABEL_NUM                                           5.1153
# YEAR                                                       1991
# YEAR_NUM                                                     15
# AGE                                           85 years and over
# AGE_NUM                                                     6.0
# ESTIMATE                                                   74.8
# FLAG                                                        NaN
# Name: 3304, dtype: object

# %%
deathrates
# Out:
#                     INDICATOR  \
# 0     Death rates for suicide
# 1     Death rates for suicide
# 2     Death rates for suicide
# 3     Death rates for suicide
# 4     Death rates for suicide
# ...                       ...
# 6385  Death rates for suicide
# 6386  Death rates for suicide
# 6387  Death rates for suicide
# 6388  Death rates for suicide
# 6389  Death rates for suicide
#
#                                                    UNIT  UNIT_NUM  \
# 0     Deaths per 100,000 resident population, age-ad...         1
# 1     Deaths per 100,000 resident population, age-ad...         1
# 2     Deaths per 100,000 resident population, age-ad...         1
# 3     Deaths per 100,000 resident population, age-ad...         1
# 4     Deaths per 100,000 resident population, age-ad...         1
# ...                                                 ...       ...
# 6385      Deaths per 100,000 resident population, crude         2
# ...

# %%
import matplotlib.pyplot as plt

# %%
# First, filter out the rows where 'STUB_NAME' is 'Sex' as indicated in the user's code snippet
#filtered_data_without_sex = deathrates[deathrates['STUB_NAME'] != 'Sex']
#pd.set_option('display.max_rows', 500)

# Now, we repeat the previous steps but with the filtered data
grouped_data = deathrates.groupby(['STUB_NAME', 'YEAR']).agg({'ESTIMATE': 'mean'}).reset_index()
pivot_data = grouped_data.pivot(index='YEAR', columns='STUB_NAME', values='ESTIMATE')
display(pivot_data)

plt.figure(figsize=(15, 8))
for race in pivot_data.columns:
    plt.plot(pivot_data.index, pivot_data[race], label=race)

plt.title('Death Rates for Suicide by Race Over Years')
plt.xlabel('Year')
plt.ylabel('Death Rate per 100,000')
plt.legend(title='Race')
plt.grid(True)
plt.show()
# Out:
# STUB_NAME        Age     Sex  Sex and age  Sex and race  \
# YEAR
# 1950       17.100000  12.425    18.374074      8.737500
# 1960       15.757143  11.750    17.266667      8.537500
# 1970       15.550000  12.650    16.617857      9.662500
# 1980       14.657143  12.425    16.057143      9.900000
# 1981       14.585714  12.575    15.953571     10.125000
# 1982       14.892857  12.750    16.342857      9.675000
# 1983       14.985714  12.625    16.546429      9.950000
# 1984       15.278571  12.925    16.814286      9.875000
# 1985       15.414286  12.875    17.067857      9.762500
# 1986       16.050000  13.375    17.839286     10.358333
# 1987       16.007143  13.200    17.896429     10.283333
# 1988       15.557143  12.875    17.339286      9.618750
# 1989       15.407143  12.675    17.225000      9.625000
# 1990       15.585714  12.875    17.403571      9.931250
# 1991       15.364286  12.675    17.160714      9.537500
# 1992       14.857143  12.300    16.496429      9.262500
# ...
